# %%
import seaborn as sns #good for visuals
import pandas as pd #good for analysis

# %%
url = "https://raw.githubusercontent.com/chiharuishida/Tutorialdata/main/ad_dataset_withheaders.csv"
adclickdata= pd.read_csv(url)
adclickdata
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 0        68.95   35     256.09  Female         No
# 1        80.23   31     193.77    Male         No
# 2        69.47   26     236.50  Female         No
# 3        74.15   29     245.89    Male         No
# 4        68.37   35     225.58  Female         No
# ..         ...  ...        ...     ...        ...
# 995      72.97   30     208.58    Male        Yes
# 996      51.30   45     134.42    Male        Yes
# 997      51.63   51     120.37    Male        Yes
# 998      55.55   19     187.95  Female         No
# 999      45.01   26     178.35  Female        Yes
#
# [1000 rows x 5 columns]

# %%
adclickdata.head(10)
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
adclickdata.describe()
# Out:
#          Site_Time          Age    DailyTime
# count  1000.000000  1000.000000  1000.000000
# mean     65.000200    36.009000   180.000100
# std      15.853615     8.785562    43.902339
# min      32.600000    19.000000   104.780000
# 25%      51.360000    29.000000   138.830000
# 50%      68.215000    35.000000   183.130000
# 75%      78.547500    42.000000   218.792500
# max      91.430000    61.000000   269.960000

# %%
adclickdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
adclickdata['Gender'].value_counts()
# Out:
# Female    519
# Male      481
# Name: Gender, dtype: int64

# %%
adclickdata.corr()
# Out:
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.pairplot(adclickdata)

# %%
sns.scatterplot(x="Site_Time", y="DailyTime", data=adclickdata)

# %%
sns.lmplot(x="Site_Time",y="DailyTime", data=adclickdata)

# %%
sns.scatterplot(x="Site_Time", y="DailyTime", hue="Gender", data=adclickdata)

# %%
sns.lmplot(x="Site_Time", y="DailyTime", hue="Gender", data=adclickdata)

# %%
sns.countplot(x='Gender', data=adclickdata)

# %%
sns.countplot(x='Gender', data=adclickdata, color='r' )

# %%
adclickdata_AdClicking=adclickdata.groupby("Gender")
adclickdata_AdClicking.mean()
# Out:
#         Site_Time        Age   DailyTime
# Gender
# Female  65.289287  36.186898  178.816763
# Male    64.688274  35.817048  181.276923

# %%
sns.boxplot(x='AdClicking',y='Site_Time', data=adclickdata)

# %%
sns.boxplot(x="AdClicking", y="Site_Time", hue="Gender", data=adclickdata)

# %%
AdClicking_top3_adclick= adclickdata.nlargest(3, "Site_Time")
AdClicking_top3_adclick
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 533      91.43   39     209.91    Male         No
# 860      91.37   45     182.65    Male        Yes
# 927      91.15   38     184.98  Female         No
